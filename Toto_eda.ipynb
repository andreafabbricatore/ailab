# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Unfiltered data are provided for the SmartSeq experiment, in this section we will explore them. Firstly, we load and observe them.

# %%
unfilt_mcf_smarts = pd.read_csv("data/SmartSeq/MCF7_SmartS_Unfiltered_Data.txt", sep=" ")
mcf_meta = pd.read_table("data/SmartSeq/MCF7_SmartS_MetaData.tsv")

unfilt_hcc_smarts = pd.read_csv("data/SmartSeq/HCC1806_SmartS_Unfiltered_Data.txt", sep=" ")
hcc_meta = pd.read_table("data/SmartSeq/HCC1806_SmartS_MetaData.tsv")

# %%
unfilt_mcf_smarts
# Out:
#            output.STAR.1_A10_Hypo_S28_Aligned.sortedByCoord.out.bam
# WASH7P                                                     0         \
# MIR6859-1                                                  0
# WASH9P                                                     1
# OR4F29                                                     0
# MTND1P23                                                   0
# ...                                                      ...
# MT-TE                                                      4
# MT-CYB                                                   270
# MT-TT                                                      0
# MT-TP                                                      5
# MAFIP                                                      8
#
#            output.STAR.1_A11_Hypo_S29_Aligned.sortedByCoord.out.bam
# WASH7P                                                     0         \
# MIR6859-1                                                  0
# ...

# %%
unfilt_hcc_smarts
# Out:
#           output.STAR.PCRPlate1A10_Normoxia_S123_Aligned.sortedByCoord.out.bam
# WASH7P                                                    0                     \
# CICP27                                                    0
# DDX11L17                                                  0
# WASH9P                                                    0
# OR4F29                                                    2
# ...                                                     ...
# MT-TE                                                    22
# MT-CYB                                                 4208
# MT-TT                                                    26
# MT-TP                                                    66
# MAFIP                                                     0
#
#           output.STAR.PCRPlate1A12_Normoxia_S26_Aligned.sortedByCoord.out.bam
# WASH7P                                                    0                    \
# ...

# %% [markdown]
# Comment on rows, columns and dimension. Now let's give a look to the metadata

# %%
mcf_meta
# Out:
#                                               Filename Cell Line
# 0    output.STAR.1_A10_Hypo_S28_Aligned.sortedByCoo...      MCF7  \
# 1    output.STAR.1_A11_Hypo_S29_Aligned.sortedByCoo...      MCF7
# 2    output.STAR.1_A12_Hypo_S30_Aligned.sortedByCoo...      MCF7
# 3    output.STAR.1_A1_Norm_S1_Aligned.sortedByCoord...      MCF7
# 4    output.STAR.1_A2_Norm_S2_Aligned.sortedByCoord...      MCF7
# ..                                                 ...       ...
# 378  output.STAR.4_H5_Norm_S359_Aligned.sortedByCoo...      MCF7
# 379  output.STAR.4_H6_Norm_S360_Aligned.sortedByCoo...      MCF7
# 380  output.STAR.4_H7_Hypo_S379_Aligned.sortedByCoo...      MCF7
# 381  output.STAR.4_H8_Hypo_S380_Aligned.sortedByCoo...      MCF7
# 382  output.STAR.4_H9_Hypo_S381_Aligned.sortedByCoo...      MCF7
#
#               Lane  Pos Condition  Hours Cell name
# 0    output.STAR.1  A10      Hypo     72       S28  \
# 1    output.STAR.1  A11      Hypo     72       S29
# ...

# %%
hcc_meta
# Out:
#                                               Filename Cell Line  PCR Plate
# 0    output.STAR.PCRPlate1A10_Normoxia_S123_Aligned...   HCC1806          1  \
# 1    output.STAR.PCRPlate1A12_Normoxia_S26_Aligned....   HCC1806          1
# 2    output.STAR.PCRPlate1A1_Hypoxia_S97_Aligned.so...   HCC1806          1
# 3    output.STAR.PCRPlate1A2_Hypoxia_S104_Aligned.s...   HCC1806          1
# 4    output.STAR.PCRPlate1A3_Hypoxia_S4_Aligned.sor...   HCC1806          1
# ..                                                 ...       ...        ...
# 238  output.STAR.PCRPlate4H10_Normoxia_S210_Aligned...   HCC1806          4
# 239  output.STAR.PCRPlate4H11_Normoxia_S214_Aligned...   HCC1806          4
# 240  output.STAR.PCRPlate4H2_Hypoxia_S199_Aligned.s...   HCC1806          4
# 241  output.STAR.PCRPlate4H7_Normoxia_S205_Aligned....   HCC1806          4
# 242  output.STAR.PCRPlate4H9_Normoxia_S236_Aligned....   HCC1806          4
#
# ...

# %% [markdown]
# The metadata describe the columns, that is each cell. They give information on the condition of the cell, and other information. Now we check if there are some missing values.

# %%
unfilt_mcf_smarts.isnull().any().any()
# Out:
# False

# %%
unfilt_hcc_smarts.isnull().any().any()
# Out:
# False

# %% [markdown]
# Both datasets are fine. Now we ensure that all the value are integers.

# %%
unfilt_mcf_smarts.applymap(lambda x: isinstance(x, int)).all().all()
# Out:
# True

# %%
unfilt_hcc_smarts.applymap(lambda x: isinstance(x, int)).all().all()
# Out:
# True
